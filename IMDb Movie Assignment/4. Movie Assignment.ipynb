# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
import warnings

# This code is disabling warning messages from being displayed in the notebook
# It imports the warnings module, which is a built-in Python module for handling warnings
# Then it calls filterwarnings('ignore') which suppresses all warning messages
# This is often done to keep the notebook clean, especially when using libraries 
# that might generate numerous warnings that aren't critical to the analysis

warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv("./2. Movie Assignment Data.csv")
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
movies.info()  # display the data types and non-null counts
movies.describe()  # display summary statistics for numerical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
#  13  cast_total_facebook_likes  5043 non-null   int64
#  14  actor_3_name               5020 non-null   object
#  15  facenumber_in_poster       5030 non-null   float64
#  16  plot_keywords              4890 non-null   object
#  17  movie_imdb_link            5043 non-null   object
#  18  num_user_for_reviews       5022 non-null   float64
#  19  language                   5029 non-null   object
#  20  country                    5038 non-null   object
#  21  content_rating             4740 non-null   object
#  22  budget                     4551 non-null   float64
#  23  title_year                 4935 non-null   float64
#  24  actor_2_facebook_likes     5030 non-null   float64
#  25  imdb_score                 5043 non-null   float64
#  26  aspect_ratio               4714 non-null   float64
#  27  movie_facebook_likes       5043 non-null   int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                133.000000              614.000000  5.340988e+06
# 50%                371.500000              988.000000  2.551750e+07
# 75%                636.000000            11000.000000  6.230944e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     5.043000e+03                5043.000000           5030.000000
# mean      8.366816e+04                9699.063851              1.371173
# std       1.384853e+05               18163.799124              2.013576
# min       5.000000e+00                   0.000000              0.000000
# 25%       8.593500e+03                1411.000000              0.000000
# 50%       3.435900e+04                3090.000000              1.000000
# 75%       9.630900e+04               13756.500000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           5022.000000  4.551000e+03  4935.000000
# mean             272.770808  3.975262e+07  2002.470517
# std              377.982886  2.061149e+08    12.474599
# min                1.000000  2.180000e+02  1916.000000
# 25%               65.000000  6.000000e+06  1999.000000
# 50%              156.000000  2.000000e+07  2005.000000
# 75%              326.000000  4.500000e+07  2011.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             5030.000000  5043.000000   4714.000000           5043.000000
# mean              1651.754473     6.442138      2.220403           7525.964505
# std               4042.438863     1.125116      1.385113          19320.445110
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                281.000000     5.800000      1.850000              0.000000
# 50%                595.000000     6.600000      2.350000            166.000000
# 75%                918.000000     7.200000      2.350000           3000.000000
# max             137000.000000     9.500000     16.000000         349000.000000

# %%
# Display DataFrame shape (rows, columns)
print("\nDataFrame Shape:")
print("--------------")
print(f"Rows: {movies.shape[0]}")
print(f"Columns: {movies.shape[1]}")
# Out:
# DataFrame Shape:
# --------------
# Rows: 5043
# Columns: 28

# %%
# Display column names and data types
print("\nColumn Names and Data Types:")
print("--------------------------")
print(movies.dtypes)
# Out:
# Column Names and Data Types:
# --------------------------
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %%
# Display basic statistics of numerical columns
print("\nNumerical Columns Statistics:")
print("--------------------------")
print(movies.describe())
# Out:
# Numerical Columns Statistics:
# --------------------------
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                133.000000              614.000000  5.340988e+06
# 50%                371.500000              988.000000  2.551750e+07
# 75%                636.000000            11000.000000  6.230944e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     5.043000e+03                5043.000000           5030.000000
# mean      8.366816e+04                9699.063851              1.371173
# std       1.384853e+05               18163.799124              2.013576
# min       5.000000e+00                   0.000000              0.000000
# 25%       8.593500e+03                1411.000000              0.000000
# 50%       3.435900e+04                3090.000000              1.000000
# 75%       9.630900e+04               13756.500000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           5022.000000  4.551000e+03  4935.000000
# mean             272.770808  3.975262e+07  2002.470517
# std              377.982886  2.061149e+08    12.474599
# min                1.000000  2.180000e+02  1916.000000
# 25%               65.000000  6.000000e+06  1999.000000
# 50%              156.000000  2.000000e+07  2005.000000
# 75%              326.000000  4.500000e+07  2011.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             5030.000000  5043.000000   4714.000000           5043.000000
# mean              1651.754473     6.442138      2.220403           7525.964505
# std               4042.438863     1.125116      1.385113          19320.445110
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                281.000000     5.800000      1.850000              0.000000
# 50%                595.000000     6.600000      2.350000            166.000000
# 75%                918.000000     7.200000      2.350000           3000.000000
# max             137000.000000     9.500000     16.000000         349000.000000

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
print("Column-wise Null Count:")
print("--------------------------")
movies.isnull().sum()  # Count null values in each column using isnull().sum()
# Out:
# Column-wise Null Count:
# --------------------------
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here
print("\nRow-wise Null Count:")  # display null counts for each row
print("--------------------------")
row_null_count = movies.isnull().sum(axis=1) # count nulls in each row
print(f"Total rows with null values: {(row_null_count > 0).sum()}") # count rows with nulls
print(f"Maximum nulls in a single row: {row_null_count.max()}") # count max nulls in a row
# Out:
# Row-wise Null Count:
# --------------------------
# Total rows with null values: 1288
# Maximum nulls in a single row: 15

# %%
# Write your code for column-wise null percentages here
print("\nPercentage of Null Values in Each Column:")
print("------------------------------------")
null_percentage = (movies.isnull().sum() / len(movies) * 100).round(2)  # calculate percentage of nulls
for column, percentage in null_percentage.items():  # iterate through each column and its null percentage
        print(f"{column}: {percentage}%") # display percentage of nulls in each column
# Out:
# Percentage of Null Values in Each Column:
# ------------------------------------
# color: 0.38%
# director_name: 2.06%
# num_critic_for_reviews: 0.99%
# duration: 0.3%
# director_facebook_likes: 2.06%
# actor_3_facebook_likes: 0.46%
# actor_2_name: 0.26%
# actor_1_facebook_likes: 0.14%
# gross: 17.53%
# genres: 0.0%
# actor_1_name: 0.14%
# movie_title: 0.0%
# num_voted_users: 0.0%
# cast_total_facebook_likes: 0.0%
# actor_3_name: 0.46%
# facenumber_in_poster: 0.26%
# plot_keywords: 3.03%
# movie_imdb_link: 0.0%
# num_user_for_reviews: 0.42%
# language: 0.28%
# country: 0.1%
# content_rating: 6.01%
# budget: 9.76%
# title_year: 2.14%
# actor_2_facebook_likes: 0.26%
# imdb_score: 0.0%
# aspect_ratio: 6.52%
# movie_facebook_likes: 0.0%

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the ``movies`` with respect to the ``ratings,`` ``gross collection``, ``popularity`` of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# First, let's see what columns we actually have
print("Available columns in DataFrame:")
print(movies.columns.tolist())

# Create list of columns to drop
columns_to_drop = ['color', 'director_facebook_likes', 'actor_1_facebook_likes', 
                   'actor_2_facebook_likes', 'actor_3_facebook_likes', 
                   'actor_2_name', 'actor_3_name', 'cast_total_facebook_likes',
                   'duration', 'facenumber_in_poster', 'content_rating',
                   'country', 'movie_imdb_link', 'aspect_ratio', 'plot_keywords']

# Drop only the columns that exist
existing_columns = [col for col in columns_to_drop if col in movies.columns]
movies.drop(columns=existing_columns, inplace=True)

# Verify remaining columns
print("\nRemaining Columns After Dropping:")
print(movies.columns.tolist())
# Out:
# Available columns in DataFrame:
# ['color', 'director_name', 'num_critic_for_reviews', 'duration', 'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name', 'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name', 'movie_title', 'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name', 'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link', 'num_user_for_reviews', 'language', 'country', 'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score', 'aspect_ratio', 'movie_facebook_likes']
#
# Remaining Columns After Dropping:
# ['director_name', 'num_critic_for_reviews', 'gross', 'genres', 'actor_1_name', 'movie_title', 'num_voted_users', 'num_user_for_reviews', 'language', 'budget', 'title_year', 'imdb_score', 'movie_facebook_likes']

# %%
# Write your code for column-wise null percentages here
print("\nPercentage of Null Values in Each Column:")
print("------------------------------------")
null_percentage = (movies.isnull().sum() / len(movies) * 100).round(2)  # calculate percentage of nulls
for column, percentage in null_percentage.items():  # iterate through each column and its null percentage
        print(f"{column}: {percentage}%") # display percentage of nulls in each column
# Out:
# Percentage of Null Values in Each Column:
# ------------------------------------
# director_name: 2.06%
# num_critic_for_reviews: 0.99%
# gross: 17.53%
# genres: 0.0%
# actor_1_name: 0.14%
# movie_title: 0.0%
# num_voted_users: 0.0%
# num_user_for_reviews: 0.42%
# language: 0.28%
# budget: 9.76%
# title_year: 2.14%
# imdb_score: 0.0%
# movie_facebook_likes: 0.0%

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here
columns_to_drop = null_percentage[null_percentage > 5].index.tolist() # get columns with more than 5% nulls

# Print columns that will be dropped
print("Columns with >5% null values that will be dropped:")
for col in columns_to_drop:
        print(f"- {col}: {null_percentage[col]: .2f} % ")
# Out:
# Columns with >5% null values that will be dropped:
# - gross:  17.53 %
# - budget:  9.76 %

# %%
# Write your code for column-wise null percentages here
print("\nPercentage of Null Values in Each Column:")
print("------------------------------------")
null_percentage = (movies.isnull().sum() / len(movies) * 100).round(2)  # calculate percentage of nulls
for column, percentage in null_percentage.items():  # iterate through each column and its null percentage
        print(f"{column}: {percentage}%") # display percentage of nulls in each column
# Out:
# Percentage of Null Values in Each Column:
# ------------------------------------
# director_name: 2.06%
# num_critic_for_reviews: 0.99%
# gross: 17.53%
# genres: 0.0%
# actor_1_name: 0.14%
# movie_title: 0.0%
# num_voted_users: 0.0%
# num_user_for_reviews: 0.42%
# language: 0.28%
# budget: 9.76%
# title_year: 2.14%
# imdb_score: 0.0%
# movie_facebook_likes: 0.0%

# %%
print(movies.isnull().sum()) # display null counts for each column

# print((movies.isnull().sum() / len(movies) * 100).round(2)) # display percentage of nulls in each column
# Out:
# director_name             104
# num_critic_for_reviews     50
# gross                     884
# genres                      0
# actor_1_name                7
# movie_title                 0
# num_voted_users             0
# num_user_for_reviews       21
# language                   14
# budget                    492
# title_year                108
# imdb_score                  0
# movie_facebook_likes        0
# dtype: int64

# %% [markdown]
# -  ### Subtask 2.4: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
movies['language'].fillna('English', inplace=True)  # fill NaN values in 'language' column with 'English'
movies['director_name'].fillna('Unknown', inplace = True) # fill NaN values in 'director_name' column with 'Unknown'
movies['num_critic_for_reviews'].fillna('0', inplace = True) # fill NaN values in 'num_critic_for_reviews' column with 0
movies['num_user_for_reviews'].fillna('0', inplace = True) # fill NaN values in 'num_user_for_reviews' column with 0
movies['title_year'].fillna('0', inplace = True) # fill NaN values in 'title_year' column with 0

# %%
print(movies.isnull().sum()) # display null counts for each column
# Out:
# director_name               0
# num_critic_for_reviews      0
# gross                     884
# genres                      0
# actor_1_name                7
# movie_title                 0
# num_voted_users             0
# num_user_for_reviews        0
# language                    0
# budget                    492
# title_year                  0
# imdb_score                  0
# movie_facebook_likes        0
# dtype: int64

# %%
# Get initial and current row counts
initial_rows = len(movies)
current_rows = movies.shape[0]

# Calculate percentage with proper rounding
retention_percentage = round((current_rows / initial_rows * 100), 2)

# Print the results
print("Row Retention Summary:")
print("-" * 30)
print(f"Initial number of rows: {initial_rows}")
print(f"Current number of rows: {current_rows}")
print(f"Retained rows percentage: {retention_percentage}%")
# Out:
# Row Retention Summary:
# ------------------------------
# Initial number of rows: 5043
# Current number of rows: 5043
# Retained rows percentage: 100.0%

# %% [markdown]
# -  ### Subtask 2.5: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here
# Write your code for column-wise null percentages here
print("\nPercentage of Null Values in Each Column:")
print("------------------------------------")
null_percentage = (movies.isnull().sum() / len(movies) * 100).round(2)  # calculate percentage of nulls
for column, percentage in null_percentage.items():  # iterate through each column and its null percentage
        print(f"{column}: {percentage}%") # display percentage of nulls in each column
# Out:
# Percentage of Null Values in Each Column:
# ------------------------------------
# director_name: 0.0%
# num_critic_for_reviews: 0.0%
# gross: 17.53%
# genres: 0.0%
# actor_1_name: 0.14%
# movie_title: 0.0%
# num_voted_users: 0.0%
# num_user_for_reviews: 0.0%
# language: 0.0%
# budget: 9.76%
# title_year: 0.0%
# imdb_score: 0.0%
# movie_facebook_likes: 0.0%

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Display first few rows of budget and gross columns
print("Sample of original values:")
print("-" * 30)
print(movies[['budget', 'gross']].head())

# Display basic statistics
print("\nBasic statistics:")
print("-" * 30)
print(movies[['budget', 'gross']].describe())

# Check unique values (first 5) to understand the format
print("\nSample of unique values in budget:")
print("-" * 30)
print(movies['budget'].unique()[:5])
print("\nSample of unique values in gross:")
print("-" * 30)
print(movies['gross'].unique()[:5])
# Out:
# Sample of original values:
# ------------------------------
#         budget        gross
# 0  237000000.0  760505847.0
# 1  300000000.0  309404152.0
# 2  245000000.0  200074175.0
# 3  250000000.0  448130642.0
# 4          NaN          NaN
#
# Basic statistics:
# ------------------------------
#              budget         gross
# count  4.551000e+03  4.159000e+03
# mean   3.975262e+07  4.846841e+07
# std    2.061149e+08  6.845299e+07
# min    2.180000e+02  1.620000e+02
# 25%    6.000000e+06  5.340988e+06
# 50%    2.000000e+07  2.551750e+07
# 75%    4.500000e+07  6.230944e+07
# max    1.221550e+10  7.605058e+08
#
# Sample of unique values in budget:
# ------------------------------
# [2.37e+08 3.00e+08 2.45e+08 2.50e+08      nan]
#
# Sample of unique values in gross:
# ------------------------------
# [7.60505847e+08 3.09404152e+08 2.00074175e+08 4.48130642e+08
#             nan]

# %%
# Convert currency columns to numeric by removing $ and , then convert to millions
movies['budget'] = movies['budget'].replace('[\$,]', '', regex=True).astype(float) / 1_000_000
movies['gross'] = movies['gross'].replace('[\$,]', '', regex=True).astype(float) / 1_000_000

# Verify the conversion
print("Sample of converted values (in millions):")
print(movies[['budget', 'gross']].head())
# Out:
# Sample of converted values (in millions):
#    budget       gross
# 0   237.0  760.505847
# 1   300.0  309.404152
# 2   245.0  200.074175
# 3   250.0  448.130642
# 4     NaN         NaN

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Plot `profit` (y-axis) vs `budget` (x- axis) and observe the outliers using the appropriate chart type.
#     4. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
# Create profit column
movies['profit'] = movies['gross'] - movies['budget']

# Display first few rows of the profit column
print("First few rows with profit column:")
print("-" * 30)
print(movies[['movie_title', 'budget', 'gross', 'profit']].head())
# Out:
# First few rows with profit column:
# ------------------------------
#                                          movie_title  budget       gross  \
# 0                                            Avatar    237.0  760.505847
# 1          Pirates of the Caribbean: At World's End    300.0  309.404152
# 2                                           Spectre    245.0  200.074175
# 3                             The Dark Knight Rises    250.0  448.130642
# 4  Star Wars: Episode VII - The Force Awakens    ...     NaN         NaN
#
#        profit
# 0  523.505847
# 1    9.404152
# 2  -44.925825
# 3  198.130642
# 4         NaN

# %%
# Write your code for sorting the dataframe here
movies_sorted = movies.sort_values(by='profit', ascending= False) # sort by profit in descending order
movies_sorted
# Out:
#          director_name num_critic_for_reviews       gross  \
# 0        James Cameron                  723.0  760.505847
# 29     Colin Trevorrow                  644.0  652.177271
# 26       James Cameron                  315.0  658.672302
# 3024      George Lucas                  282.0  460.935665
# 3080  Steven Spielberg                  215.0  434.949459
# ...                ...                    ...         ...
# 5036   Anthony Vallone                      0         NaN
# 5038       Scott Smith                    1.0         NaN
# 5039           Unknown                   43.0         NaN
# 5040  Benjamin Roberds                   13.0         NaN
# 5041       Daniel Hsia                   14.0    0.010443
#
#                                 genres         actor_1_name  \
# 0      Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29    Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                       Drama|Romance    Leonardo DiCaprio
# 3024   Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 3080                     Family|Sci-Fi         Henry Thomas
# ...                                ...                  ...
# 5036                       Crime|Drama       Richard Jewell
# 5038                      Comedy|Drama          Eric Mabius
# 5039      Crime|Drama|Mystery|Thriller          Natalie Zea
# 5040             Drama|Horror|Thriller          Eva Boehnke
# 5041              Comedy|Drama|Romance            Alan Ruck
#
#                               movie_title  num_voted_users  \
# 0                                 Avatar            886204
# 29                        Jurassic World            418214
# 26                               Titanic            793059
# 3024  Star Wars: Episode IV - A New Hope            911097
# 3080          E.T. the Extra-Terrestrial            281842
# ...                                   ...              ...
# 5036                     The Mongol King                36
# 5038             Signed Sealed Delivered               629
# 5039           The Following                         73839
# 5040                A Plague So Pleasant                38
# 5041                    Shanghai Calling              1255
#
#      num_user_for_reviews language     budget title_year  imdb_score  \
# 0                  3054.0  English  237.00000     2009.0         7.9
# 29                 1290.0  English  150.00000     2015.0         7.0
# 26                 2528.0  English  200.00000     1997.0         7.7
# 3024               1470.0  English   11.00000     1977.0         8.7
# 3080                515.0  English   10.50000     1982.0         7.9
# ...                   ...      ...        ...        ...         ...
# 5036                  1.0  English    0.00325     2005.0         7.8
# 5038                  6.0  English        NaN     2013.0         7.7
# 5039                359.0  English        NaN          0         7.5
# 5040                  3.0  English    0.00140     2013.0         6.3
# 5041                  9.0  English        NaN     2012.0         6.3
#
#       movie_facebook_likes      profit
# 0                    33000  523.505847
# 29                  150000  502.177271
# 26                   26000  458.672302
# 3024                 33000  449.935665
# 3080                 34000  424.449459
# ...                    ...         ...
# 5036                     4         NaN
# 5038                    84         NaN
# 5039                 32000         NaN
# 5040                    16         NaN
# 5041                   660         NaN
#
# [5043 rows x 14 columns]

# %%
# Write code for profit vs budget plot here
import matplotlib.pyplot as plt

# create a scatter plot of budget vs profit
plt.figure(figsize = (8, 5)) # set figure size  # 8 inches wide and 5 inches tall
plt.scatter(movies['budget'], movies['profit'], alpha = 0.5) # set transparency for overlapping points

# Add labels and title
plt.xlabel('Budget (millions $)')
plt.ylabel('Profit (millions $)')
plt.title('Profit vs Budget')

# Add grid for better readability
plt.grid(True, linestyle = '--', alpha = 0.7) # 

# Add a reference line at y = 0 to seprate profitable and unprofitable movies
plt.axhline(y = 0, color = 'r', linestyle = '--', alpha = 0.3)

# show plot
plt.tight_layout() # adjust layout to prevent clipping of tick-labels
plt.show()

# 1- Create a scatter plot where each point represents a movie
# 2- The x-axis represents the budget of the movie in millions of dollars
# 3- The y-axis represents the profit of the movie in millions of dollars
# 4- Points above the Red dashed line indicate profitable movies
# 5- Points below the Red dashed line indicate unprofitable movies
# 6- Outliers will be visible as points that are far from the main cluster
# 7- Alpha=0.5 makes overlapping points more visible

# %%
# Write your code to get the top 10 profiting movies here
movies_sorted[['movie_title', 'profit']].head(10) # display top 10 movies by profit
# Out:
#                                      movie_title      profit
# 0                                        Avatar   523.505847
# 29                               Jurassic World   502.177271
# 26                                      Titanic   458.672302
# 3024         Star Wars: Episode IV - A New Hope   449.935665
# 3080                 E.T. the Extra-Terrestrial   424.449459
# 17                                 The Avengers   403.279547
# 794                                The Avengers   403.279547
# 509                               The Lion King   377.783777
# 240   Star Wars: Episode I - The Phantom Menace   359.544677
# 66                              The Dark Knight   348.316061

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have noticed a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`. Note that the same `movie_title` can be there in different languages.

# %%
# Count the total number of duplicate rows (based on all columns)
total_duplicate_rows = movies.duplicated().sum() # count duplicate rows
print(f"Total numbers of duplicate rows: {total_duplicate_rows}")
# Out:
# Total numbers of duplicate rows: 47

# %%
# drop duplicate rows, keeping the first occurrence
movies.drop_duplicates(inplace = True) # drop duplicates
print(f"Shape after dropping duplicates: {movies.shape}") # display shape after dropping duplicates
# Out:
# Shape after dropping duplicates: (4996, 14)

# %%
# Check for duplicate combinations of movie title, director name, and critic reviews
all_duplicates_in_title = movies[movies.duplicated(subset=['movie_title', 'director_name', 'num_critic_for_reviews'], keep=False)]
print(f"Number of duplicate rows: {len(all_duplicates_in_title)}")
print(all_duplicates_in_title[['movie_title', 'director_name', 'num_critic_for_reviews']].head(10))
# Out:
# Number of duplicate rows: 151
#                     movie_title    director_name num_critic_for_reviews
# 6                 Spider-Man 3         Sam Raimi                  392.0
# 25                   King Kong     Peter Jackson                  446.0
# 30                     Skyfall        Sam Mendes                  750.0
# 33         Alice in Wonderland        Tim Burton                  451.0
# 38   Oz the Great and Powerful         Sam Raimi                  525.0
# 40                TRON: Legacy   Joseph Kosinski                  469.0
# 50            The Great Gatsby      Baz Luhrmann                  490.0
# 79             The Jungle Book       Jon Favreau                  370.0
# 100   The Fast and the Furious         Rob Cohen                  187.0
# 145                        Pan        Joe Wright                  256.0

# %%
# Count the total number of duplicate rows (based on all columns)
total_duplicate_rows = movies.duplicated().sum() # count duplicate rows
print(f"Total numbers of duplicate rows: {total_duplicate_rows}")
# Out:
# Total numbers of duplicate rows: 0

# %%
# Write your code for dropping duplicate values here
movies.drop_duplicates(subset=['movie_title'], keep = 'first', inplace = True) # drop duplicates based on 'movie_title' column)
movies
# Out:
#           director_name num_critic_for_reviews       gross  \
# 0         James Cameron                  723.0  760.505847
# 1        Gore Verbinski                  302.0  309.404152
# 2            Sam Mendes                  602.0  200.074175
# 3     Christopher Nolan                  813.0  448.130642
# 4           Doug Walker                      0         NaN
# ...                 ...                    ...         ...
# 5038        Scott Smith                    1.0         NaN
# 5039            Unknown                   43.0         NaN
# 5040   Benjamin Roberds                   13.0         NaN
# 5041        Daniel Hsia                   14.0    0.010443
# 5042           Jon Gunn                   43.0    0.085222
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# 3                     Action|Thriller        Tom Hardy
# 4                         Documentary      Doug Walker
# ...                               ...              ...
# 5038                     Comedy|Drama      Eric Mabius
# 5039     Crime|Drama|Mystery|Thriller      Natalie Zea
# 5040            Drama|Horror|Thriller      Eva Boehnke
# 5041             Comedy|Drama|Romance        Alan Ruck
# 5042                      Documentary      John August
#
#                                             movie_title  num_voted_users  \
# 0                                               Avatar            886204
# 1             Pirates of the Caribbean: At World's End            471220
# 2                                              Spectre            275868
# 3                                The Dark Knight Rises           1144337
# 4     Star Wars: Episode VII - The Force Awakens    ...                8
# ...                                                 ...              ...
# 5038                           Signed Sealed Delivered               629
# 5039                         The Following                         73839
# 5040                              A Plague So Pleasant                38
# 5041                                  Shanghai Calling              1255
# 5042                                 My Date with Drew              4285
#
#      num_user_for_reviews language    budget title_year  imdb_score  \
# 0                  3054.0  English  237.0000     2009.0         7.9
# 1                  1238.0  English  300.0000     2007.0         7.1
# 2                   994.0  English  245.0000     2015.0         6.8
# 3                  2701.0  English  250.0000     2012.0         8.5
# 4                       0  English       NaN          0         7.1
# ...                   ...      ...       ...        ...         ...
# 5038                  6.0  English       NaN     2013.0         7.7
# 5039                359.0  English       NaN          0         7.5
# 5040                  3.0  English    0.0014     2013.0         6.3
# 5041                  9.0  English       NaN     2012.0         6.3
# 5042                 84.0  English    0.0011     2004.0         6.6
#
#       movie_facebook_likes      profit
# 0                    33000  523.505847
# 1                        0    9.404152
# 2                    85000  -44.925825
# 3                   164000  198.130642
# 4                        0         NaN
# ...                    ...         ...
# 5038                    84         NaN
# 5039                 32000         NaN
# 5040                    16         NaN
# 5041                   660         NaN
# 5042                   456    0.084122
#
# [4917 rows x 14 columns]

# %%
# Write code for repeating subtask 2 here
top10 = movies_sorted.head(10)
top10
# Out:
#           director_name num_critic_for_reviews       gross  \
# 0         James Cameron                  723.0  760.505847
# 29      Colin Trevorrow                  644.0  652.177271
# 26        James Cameron                  315.0  658.672302
# 3024       George Lucas                  282.0  460.935665
# 3080   Steven Spielberg                  215.0  434.949459
# 17          Joss Whedon                  703.0  623.279547
# 794         Joss Whedon                  703.0  623.279547
# 509        Roger Allers                  186.0  422.783777
# 240        George Lucas                  320.0  474.544677
# 66    Christopher Nolan                  645.0  533.316061
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# 3024           Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 3080                             Family|Sci-Fi         Henry Thomas
# 17                     Action|Adventure|Sci-Fi      Chris Hemsworth
# 794                    Action|Adventure|Sci-Fi      Chris Hemsworth
# 509   Adventure|Animation|Drama|Family|Musical    Matthew Broderick
# 240            Action|Adventure|Fantasy|Sci-Fi      Natalie Portman
# 66                 Action|Crime|Drama|Thriller       Christian Bale
#
#                                      movie_title  num_voted_users  \
# 0                                        Avatar            886204
# 29                               Jurassic World            418214
# 26                                      Titanic            793059
# 3024         Star Wars: Episode IV - A New Hope            911097
# 3080                 E.T. the Extra-Terrestrial            281842
# 17                                 The Avengers            995415
# 794                                The Avengers            995415
# 509                               The Lion King            644348
# 240   Star Wars: Episode I - The Phantom Menace            534658
# 66                              The Dark Knight           1676169
#
#      num_user_for_reviews language  budget title_year  imdb_score  \
# 0                  3054.0  English   237.0     2009.0         7.9
# 29                 1290.0  English   150.0     2015.0         7.0
# 26                 2528.0  English   200.0     1997.0         7.7
# 3024               1470.0  English    11.0     1977.0         8.7
# 3080                515.0  English    10.5     1982.0         7.9
# 17                 1722.0  English   220.0     2012.0         8.1
# 794                1722.0  English   220.0     2012.0         8.1
# 509                 656.0  English    45.0     1994.0         8.5
# 240                3597.0  English   115.0     1999.0         6.5
# 66                 4667.0  English   185.0     2008.0         9.0
#
#       movie_facebook_likes      profit
# 0                    33000  523.505847
# 29                  150000  502.177271
# 26                   26000  458.672302
# 3024                 33000  449.935665
# 3080                 34000  424.449459
# 17                  123000  403.279547
# 794                 123000  403.279547
# 509                  17000  377.783777
# 240                  13000  359.544677
# 66                   37000  348.316061

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'
IMDb_Top_250 = movies[movies['num_voted_users'] > 25000].sort_values(by='imdb_score', ascending=False).head(250).copy()
IMDb_Top_250['Rank'] = range(1, 251)
IMDb_Top_250
# Out:
#              director_name num_critic_for_reviews       gross  \
# 1937        Frank Darabont                  199.0   28.341469
# 3466  Francis Ford Coppola                  208.0  134.821952
# 3481               Unknown                   54.0         NaN
# 66       Christopher Nolan                  645.0  533.316061
# 2837  Francis Ford Coppola                  149.0   57.300000
# ...                    ...                    ...         ...
# 1601        Neill Blomkamp                  472.0  115.646235
# 1603        Clint Eastwood                  229.0   90.135191
# 4158            Mel Brooks                  129.0   86.300000
# 2356         Kevin Costner                   92.0  184.208848
# 4266     Richard Linklater                  211.0    5.792822
#
#                             genres      actor_1_name  \
# 1937                   Crime|Drama    Morgan Freeman
# 3466                   Crime|Drama         Al Pacino
# 3481          Crime|Drama|Thriller     Kirsten Dunst
# 66     Action|Crime|Drama|Thriller    Christian Bale
# 2837                   Crime|Drama    Robert De Niro
# ...                            ...               ...
# 1601        Action|Sci-Fi|Thriller    Sharlto Copley
# 1603  Crime|Drama|Mystery|Thriller        John Doman
# 4158                        Comedy     Madeline Kahn
# 2356       Adventure|Drama|Western    Mary McDonnell
# 4266                 Drama|Romance  Vernon Dobtcheff
#
#                     movie_title  num_voted_users num_user_for_reviews  \
# 1937  The Shawshank Redemption           1689764               4144.0
# 3466             The Godfather           1155770               2238.0
# 3481         Fargo                        170055                173.0
# 66             The Dark Knight           1676169               4667.0
# 2837    The Godfather: Part II            790926                650.0
# ...                         ...              ...                  ...
# 1601                District 9            531737               1262.0
# 1603              Mystic River            338415                935.0
# 4158        Young Frankenstein            112671                315.0
# 2356        Dances with Wolves            186485                382.0
# 4266             Before Sunset            168398                492.0
#
#      language  budget title_year  imdb_score  movie_facebook_likes  \
# 1937  English    25.0     1994.0         9.3                108000
# 3466  English     6.0     1972.0         9.2                 43000
# 3481  English     NaN          0         9.0                 61000
# 66    English   185.0     2008.0         9.0                 37000
# 2837  English    13.0     1974.0         9.0                 14000
# ...       ...     ...        ...         ...                   ...
# 1601  English    30.0     2009.0         8.0                 22000
# 1603  English    25.0     2003.0         8.0                 12000
# 4158  English     2.8     1974.0         8.0                 14000
# 2356  English    22.0     1990.0         8.0                     0
# 4266  English     2.7     2004.0         8.0                 13000
#
#           profit  Rank
# 1937    3.341469     1
# 3466  128.821952     2
# 3481         NaN     3
# 66    348.316061     4
# 2837   44.300000     5
# ...          ...   ...
# 1601   85.646235   246
# 1603   65.135191   247
# 4158   83.500000   248
# 2356  162.208848   249
# 4266    3.092822   250
#
# [250 rows x 15 columns]

# %%
# Write your code to extract top foreign language films from 'IMDb_Top_250' here
Top_Foreign_Lang_Film = IMDb_Top_250[IMDb_Top_250['language'] != 'English'] # filter out English language films
Top_Foreign_Lang_Film = Top_Foreign_Lang_Film.sort_values(by='imdb_score', ascending=False) # sort by IMDb score
Top_Foreign_Lang_Film
# Out:
#                          director_name num_critic_for_reviews      gross  \
# 4498                      Sergio Leone                  181.0   6.100000
# 4747                    Akira Kurosawa                  153.0   0.269061
# 4029                Fernando Meirelles                  214.0   7.563397
# 2373                    Hayao Miyazaki                  246.0  10.049886
# 4921                      Majid Majidi                   46.0   0.925402
# 4259  Florian Henckel von Donnersmarck                  215.0  11.284657
# 3870                        Raja Menon                   39.0        NaN
# 2970                 Wolfgang Petersen                   96.0  11.433134
# 4659                    Asghar Farhadi                  354.0   7.098492
# 1298                Jean-Pierre Jeunet                  242.0  33.201661
# 3685           Rakeysh Omprakash Mehra                   33.0   2.197331
# 2323                    Hayao Miyazaki                  174.0   2.298191
# 1329                    S.S. Rajamouli                   44.0   6.498000
# 4105                    Chan-wook Park                  305.0   2.181290
# 2734                        Fritz Lang                  260.0   0.026435
# 4033                 Thomas Vinterberg                  349.0   0.610968
# 2829               Oliver Hirschbiegel                  192.0   5.501940
# 4160                   Rajkumar Hirani                   15.0        NaN
# 2047                    Hayao Miyazaki                  212.0   4.710455
# 3550                  Denis Villeneuve                  226.0   6.857096
# 4000              Juan José Campanella                  262.0  20.167424
# 2551                Guillermo del Toro                  406.0  37.623143
# 3423                   Katsuhiro Ôtomo                  150.0   0.439162
# 1061                  Andrei Tarkovsky                  144.0        NaN
# 3553                      José Padilha                  142.0   0.008060
# 4267             Alejandro G. Iñárritu                  157.0   5.383834
# 4461                 Thomas Vinterberg                   98.0   1.647780
# 2830                Alejandro Amenábar                  157.0   2.086345
# 2914                       Je-kyu Kang                   86.0   1.110186
# 4897                      Sergio Leone                  122.0   3.500000
# 2802                   Julian Schnabel                  259.0   5.990075
# 4144                     Walter Salles                   71.0   5.595428
# 3456                 Vincent Paronnaud                  242.0   4.443403
#
#                                   genres         actor_1_name  \
# 4498                             Western       Clint Eastwood
# 4747              Action|Adventure|Drama      Takashi Shimura
# 4029                         Crime|Drama          Alice Braga
# 2373  Adventure|Animation|Family|Fantasy       Bunta Sugawara
# 4921                        Drama|Family       Bahare Seddiqi
# 4259                      Drama|Thriller       Sebastian Koch
# 3870   Action|Drama|History|Thriller|War          Nimrat Kaur
# 2970        Adventure|Drama|Thriller|War      Jürgen Prochnow
# 4659                       Drama|Mystery      Shahab Hosseini
# 1298                      Comedy|Romance    Mathieu Kassovitz
# 3685        Comedy|Drama|History|Romance          Anupam Kher
# 2323         Adventure|Animation|Fantasy        Minnie Driver
# 1329  Action|Adventure|Drama|Fantasy|War     Tamannaah Bhatia
# 4105              Drama|Mystery|Thriller         Min-sik Choi
# 2734                        Drama|Sci-Fi        Brigitte Helm
# 4033                               Drama     Thomas Bo Larsen
# 2829         Biography|Drama|History|War   Thomas Kretschmann
# 4160                Comedy|Drama|Romance          Vidya Balan
# 2047  Adventure|Animation|Family|Fantasy       Christian Bale
# 3550                   Drama|Mystery|War         Lubna Azabal
# 4000              Drama|Mystery|Thriller        Ricardo Darín
# 2551                   Drama|Fantasy|War        Ivana Baquero
# 3423             Action|Animation|Sci-Fi         Mitsuo Iwata
# 1061                Drama|Mystery|Sci-Fi     Donatas Banionis
# 3553         Action|Crime|Drama|Thriller         Wagner Moura
# 4267                      Drama|Thriller      Adriana Barraza
# 4461                               Drama       Ulrich Thomsen
# 2830             Biography|Drama|Romance          Belén Rueda
# 2914                    Action|Drama|War         Min-sik Choi
# 4897                Action|Drama|Western       Clint Eastwood
# 2802                     Biography|Drama   Emmanuelle Seigner
# 4144                               Drama  Fernanda Montenegro
# 3456       Animation|Biography|Drama|War    Catherine Deneuve
#
#                               movie_title  num_voted_users  \
# 4498      The Good, the Bad and the Ugly            503509
# 4747                       Seven Samurai            229012
# 4029                         City of God            533200
# 2373                       Spirited Away            417971
# 4921                  Children of Heaven             27882
# 4259                 The Lives of Others            259379
# 3870                             Airlift             30977
# 2970                            Das Boot            168203
# 4659                        A Separation            151812
# 1298                              Amélie            534262
# 3685                     Rang De Basanti             70233
# 2323                   Princess Mononoke            221552
# 1329            Baahubali: The Beginning             62756
# 4105                              Oldboy            356181
# 2734                          Metropolis            111841
# 4033                            The Hunt            170155
# 2829                            Downfall            248354
# 4160                Lage Raho Munna Bhai             27569
# 2047                Howl's Moving Castle            214091
# 3550                           Incendies             80429
# 4000            The Secret in Their Eyes            131831
# 2551                     Pan's Labyrinth            467234
# 3423                               Akira            106160
# 1061                             Solaris             54057
# 3553                         Elite Squad             81644
# 4267                       Amores Perros            173551
# 4461                     The Celebration             65951
# 2830                      The Sea Inside             64556
# 2914  Tae Guk Gi: The Brotherhood of War             31943
# 4897                A Fistful of Dollars            147566
# 2802   The Diving Bell and the Butterfly             89906
# 4144                     Central Station             28951
# 3456                          Persepolis             70194
#
#      num_user_for_reviews    language       budget title_year  imdb_score  \
# 4498                780.0     Italian     1.200000     1966.0         8.9
# 4747                596.0    Japanese     2.000000     1954.0         8.7
# 4029                749.0  Portuguese     3.300000     2002.0         8.7
# 2373                902.0    Japanese    19.000000     2001.0         8.6
# 4921                130.0     Persian     0.180000     1997.0         8.5
# 4259                407.0      German     2.000000     2006.0         8.5
# 3870                178.0       Hindi     4.400000     2016.0         8.5
# 2970                426.0      German    14.000000     1981.0         8.4
# 4659                264.0     Persian     0.500000     2011.0         8.4
# 1298               1314.0      French    77.000000     2001.0         8.4
# 3685                321.0       Hindi          NaN     2006.0         8.4
# 2323                570.0    Japanese  2400.000000     1997.0         8.4
# 1329                410.0      Telugu    18.026148     2015.0         8.4
# 4105                809.0      Korean     3.000000     2003.0         8.4
# 2734                413.0      German     6.000000     1927.0         8.3
# 4033                249.0      Danish     3.800000     2012.0         8.3
# 2829                564.0      German    13.500000     2004.0         8.3
# 4160                106.0       Hindi   120.000000     2006.0         8.2
# 2047                330.0    Japanese    24.000000     2004.0         8.2
# 3550                156.0      French     6.800000     2010.0         8.2
# 4000                231.0     Spanish     2.000000     2009.0         8.2
# 2551               1083.0     Spanish    13.500000     2006.0         8.2
# 3423                430.0    Japanese  1100.000000     1988.0         8.1
# 1061                236.0     Russian     1.000000     1972.0         8.1
# 3553                107.0  Portuguese     4.000000     2007.0         8.1
# 4267                361.0     Spanish     2.000000     2000.0         8.1
# 4461                258.0      Danish     1.300000     1998.0         8.1
# 2830                140.0     Spanish    10.000000     2004.0         8.1
# 2914                224.0      Korean    12.800000     2004.0         8.1
# 4897                235.0     Italian     0.200000     1964.0         8.0
# 2802                175.0      French          NaN     2007.0         8.0
# 4144                257.0  Portuguese     2.900000     1998.0         8.0
# 3456                158.0      French     7.300000     2007.0         8.0
#
#       movie_facebook_likes       profit  Rank
# 4498                 20000     4.900000    10
# 4747                 11000    -1.730939    23
# 4029                 28000     4.263397    24
# 2373                 28000    -8.950114    27
# 4921                     0     0.745402    40
# 4259                 39000     9.284657    44
# 3870                 10000          NaN    52
# 2970                 11000    -2.566866    62
# 4659                 48000     6.598492    67
# 1298                 39000   -43.798339    68
# 3685                     0          NaN    71
# 2323                 11000 -2397.701809    76
# 1329                 21000   -11.528148    81
# 4105                 43000    -0.818710    84
# 2734                 12000    -5.973565    98
# 4033                 60000    -3.189032   109
# 2829                 14000    -7.998060   110
# 4160                   349          NaN   121
# 2047                 13000   -19.289545   124
# 3550                 37000     0.057096   130
# 4000                 33000    18.167424   137
# 2551                 27000    24.123143   139
# 3423                     0 -1099.560838   153
# 1061                     0          NaN   163
# 3553                 11000    -3.991940   164
# 4267                 11000     3.383834   166
# 4461                  5000     0.347780   181
# 2830                     0    -7.913655   188
# 2914                     0   -11.689814   195
# 4897                     0     3.300000   201
# 2802                 13000          NaN   212
# 4144                     0     2.695428   230
# 3456                 14000    -2.856597   241

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.  Incase of a tie in IMDb score between two directors, sort them alphabetically.

# %%
# Write your code for extracting the top 10 directors here
director_mean_scores = movies.groupby('director_name')['imdb_score'].mean().reset_index() # group by director and calculate mean IMDb score
top_directors_sorted = director_mean_scores.sort_values(by=['imdb_score', 'director_name' ], ascending=[False, True]) # sort by IMDb score and director name
top20director = top_directors_sorted.head(20) # get top 20 directors
top20director
# Out:
#                 director_name  imdb_score
# 1084           John Blanchard       9.500
# 299                 Cary Bell       8.700
# 1620         Mitchell Altieri       8.700
# 2010         Sadyk Sher-Niyaz       8.700
# 315           Charles Chaplin       8.600
# 1606             Mike Mayhall       8.600
# 428           Damien Chazelle       8.500
# 1417             Majid Majidi       8.500
# 1835               Raja Menon       8.500
# 1978               Ron Fricke       8.500
# 2060             Sergio Leone       8.475
# 373         Christopher Nolan       8.425
# 151            Asghar Farhadi       8.400
# 199             Bill Melendez       8.400
# 305           Catherine Owens       8.400
# 980                 Jay Oliva       8.400
# 1444    Marius A. Markevicius       8.400
# 1632          Moustapha Akkad       8.400
# 1838  Rakeysh Omprakash Mehra       8.400
# 1886         Richard Marquand       8.400

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
movies['genres'] = movies['genres'].str.split('|') # split genres into lists
movies['genre_1'] = movies['genres'].apply(lambda x: x[0]) # get first genre using lambda function
movies['genre_2'] = movies['genres'].apply(lambda x : x[1] if len(x) > 1 else x[0]) # get second genre using conditional
movies['genre_3'] = movies['genres'].apply(lambda x : x[2] if len(x) > 2 else x[0]) # get third genre using conditional
movies
# Out:
#           director_name num_critic_for_reviews       gross  \
# 0         James Cameron                  723.0  760.505847
# 1        Gore Verbinski                  302.0  309.404152
# 2            Sam Mendes                  602.0  200.074175
# 3     Christopher Nolan                  813.0  448.130642
# 4           Doug Walker                      0         NaN
# ...                 ...                    ...         ...
# 5038        Scott Smith                    1.0         NaN
# 5039            Unknown                   43.0         NaN
# 5040   Benjamin Roberds                   13.0         NaN
# 5041        Daniel Hsia                   14.0    0.010443
# 5042           Jon Gunn                   43.0    0.085222
#
#                                     genres     actor_1_name  \
# 0     [Action, Adventure, Fantasy, Sci-Fi]      CCH Pounder
# 1             [Action, Adventure, Fantasy]      Johnny Depp
# 2            [Action, Adventure, Thriller]  Christoph Waltz
# 3                       [Action, Thriller]        Tom Hardy
# 4                            [Documentary]      Doug Walker
# ...                                    ...              ...
# 5038                       [Comedy, Drama]      Eric Mabius
# 5039     [Crime, Drama, Mystery, Thriller]      Natalie Zea
# 5040             [Drama, Horror, Thriller]      Eva Boehnke
# 5041              [Comedy, Drama, Romance]        Alan Ruck
# 5042                         [Documentary]      John August
#
#                                             movie_title  num_voted_users  \
# 0                                               Avatar            886204
# 1             Pirates of the Caribbean: At World's End            471220
# 2                                              Spectre            275868
# 3                                The Dark Knight Rises           1144337
# 4     Star Wars: Episode VII - The Force Awakens    ...                8
# ...                                                 ...              ...
# 5038                           Signed Sealed Delivered               629
# 5039                         The Following                         73839
# 5040                              A Plague So Pleasant                38
# 5041                                  Shanghai Calling              1255
# 5042                                 My Date with Drew              4285
#
#      num_user_for_reviews language    budget title_year  imdb_score  \
# 0                  3054.0  English  237.0000     2009.0         7.9
# 1                  1238.0  English  300.0000     2007.0         7.1
# 2                   994.0  English  245.0000     2015.0         6.8
# 3                  2701.0  English  250.0000     2012.0         8.5
# 4                       0  English       NaN          0         7.1
# ...                   ...      ...       ...        ...         ...
# 5038                  6.0  English       NaN     2013.0         7.7
# 5039                359.0  English       NaN          0         7.5
# 5040                  3.0  English    0.0014     2013.0         6.3
# 5041                  9.0  English       NaN     2012.0         6.3
# 5042                 84.0  English    0.0011     2004.0         6.6
#
#       movie_facebook_likes      profit      genre_1      genre_2      genre_3
# 0                    33000  523.505847       Action    Adventure      Fantasy
# 1                        0    9.404152       Action    Adventure      Fantasy
# 2                    85000  -44.925825       Action    Adventure     Thriller
# 3                   164000  198.130642       Action     Thriller       Action
# 4                        0         NaN  Documentary  Documentary  Documentary
# ...                    ...         ...          ...          ...          ...
# 5038                    84         NaN       Comedy        Drama       Comedy
# 5039                 32000         NaN        Crime        Drama      Mystery
# 5040                    16         NaN        Drama       Horror     Thriller
# 5041                   660         NaN       Comedy        Drama      Romance
# 5042                   456    0.084122  Documentary  Documentary  Documentary
#
# [4917 rows x 17 columns]

# %%
movies_by_segment = movies.groupby(['genre_1', 'genre_2', 'genre_3'])

# %%
PopGenre = pd.DataFrame(movies_by_segment['gross'].mean()).sort_values(by = 'gross', ascending = False)
PopGenre.iloc[:10, ]
# Out:
#                                     gross
# genre_1   genre_2   genre_3
# Family    Sci-Fi    Family     434.949459
# Adventure Sci-Fi    Adventure  281.666058
#                     Thriller   221.050859
#           Drama     Fantasy    180.438840
# Comedy    Crime     Sport      158.115031
# Adventure Animation Drama      156.005190
#           Drama     Sci-Fi     155.756195
# Action    Adventure Fantasy    155.046317
#                     Sci-Fi     153.026989
# Adventure Fantasy   Adventure  131.552745

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_users_for_review` and identify the actors which have the highest mean.
#     5. Observe the change in number of voted users over decades using a bar chart. Create a column called `decade` which represents the decade to which every movie belongs to. For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. Store this in a new data frame called `df_by_decade`.

# %%
# Create a new dataframe for Mertyl steep

Meryl_Streep = movies.loc[movies.actor_1_name == 'Meryl Streep'] # filter movies where Meryl Streep is actor 1
Meryl_Streep
# Out:
#        director_name num_critic_for_reviews       gross  \
# 410     Nancy Meyers                  187.0  112.703470
# 1106   Curtis Hanson                   42.0   46.815748
# 1204     Nora Ephron                  252.0   94.125426
# 1408   David Frankel                  208.0  124.732962
# 1483  Robert Redford                  227.0   14.998070
# 1575  Sydney Pollack                   66.0   87.100000
# 1618   David Frankel                  234.0   63.536011
# 1674   Carl Franklin                   64.0   23.209440
# 1752  Stephen Frears                   87.0         NaN
# 1925  Stephen Daldry                  174.0   41.597830
# 2781  Phyllida Lloyd                  331.0   29.959436
# 3135   Robert Altman                  211.0   20.338609
# 3641  Fred Zinnemann                   38.0         NaN
#
#                                           genres  actor_1_name  \
# 410                     [Comedy, Drama, Romance]  Meryl Streep
# 1106        [Action, Adventure, Crime, Thriller]  Meryl Streep
# 1204                 [Biography, Drama, Romance]  Meryl Streep
# 1408                    [Comedy, Drama, Romance]  Meryl Streep
# 1483                      [Drama, Thriller, War]  Meryl Streep
# 1575                 [Biography, Drama, Romance]  Meryl Streep
# 1618                    [Comedy, Drama, Romance]  Meryl Streep
# 1674                                     [Drama]  Meryl Streep
# 1752  [Biography, Comedy, Drama, Music, Romance]  Meryl Streep
# 1925                            [Drama, Romance]  Meryl Streep
# 2781                 [Biography, Drama, History]  Meryl Streep
# 3135                      [Comedy, Drama, Music]  Meryl Streep
# 3641                                     [Drama]  Meryl Streep
#
#                     movie_title  num_voted_users num_user_for_reviews  \
# 410           It's Complicated             69860                214.0
# 1106            The River Wild             32544                 69.0
# 1204             Julie & Julia             79264                277.0
# 1408     The Devil Wears Prada            286178                631.0
# 1483           Lions for Lambs             41170                298.0
# 1575             Out of Africa             52339                200.0
# 1618              Hope Springs             34258                178.0
# 1674            One True Thing              9283                112.0
# 1752   Florence Foster Jenkins              2167                 32.0
# 1925                 The Hours            102123                660.0
# 2781             The Iron Lady             82327                350.0
# 3135  A Prairie Home Companion             19655                280.0
# 3641                     Julia              6454                 44.0
#
#      language  budget title_year  imdb_score  movie_facebook_likes     profit  \
# 410   English   85.00     2009.0         6.6                     0  27.703470
# 1106  English   45.00     1994.0         6.3                     0   1.815748
# 1204  English   40.00     2009.0         7.0                 13000  54.125426
# 1408  English   35.00     2006.0         6.8                     0  89.732962
# 1483  English   35.00     2007.0         6.2                     0 -20.001930
# 1575  English   31.00     1985.0         7.2                     0  56.100000
# 1618  English   30.00     2012.0         6.3                     0  33.536011
# 1674  English   30.00     1998.0         7.0                   592  -6.790560
# 1752  English   29.00     2016.0         7.1                     0        NaN
# 1925  English   25.00     2002.0         7.6                     0  16.597830
# 2781  English   13.00     2011.0         6.4                 18000  16.959436
# 3135  English   10.00     2006.0         6.8                   683  10.338609
# 3641  English    7.84     1977.0         7.4                   733        NaN
#
#         genre_1    genre_2  genre_3
# 410      Comedy      Drama  Romance
# 1106     Action  Adventure    Crime
# 1204  Biography      Drama  Romance
# 1408     Comedy      Drama  Romance
# 1483      Drama   Thriller      War
# 1575  Biography      Drama  Romance
# 1618     Comedy      Drama  Romance
# 1674      Drama      Drama    Drama
# 1752  Biography     Comedy    Drama
# 1925      Drama    Romance    Drama
# 2781  Biography      Drama  History
# 3135     Comedy      Drama    Music
# 3641      Drama      Drama    Drama

# %%
Leo_Caprio = movies.loc[movies.actor_1_name == 'Leonardo DiCaprio'] # filter movies where Leonardo DiCaprio is actor 1
Leo_Caprio
# Out:
#               director_name num_critic_for_reviews       gross  \
# 26            James Cameron                  315.0  658.672302
# 50             Baz Luhrmann                  490.0  144.812796
# 97        Christopher Nolan                  642.0  292.568851
# 179   Alejandro G. Iñárritu                  556.0  183.635922
# 257         Martin Scorsese                  267.0  102.608827
# 296       Quentin Tarantino                  765.0  162.804648
# 307            Edward Zwick                  166.0   57.366262
# 308         Martin Scorsese                  606.0  116.866727
# 326         Martin Scorsese                  233.0   77.679638
# 361         Martin Scorsese                  352.0  132.373442
# 452         Martin Scorsese                  490.0  127.968405
# 641            Ridley Scott                  238.0   39.380442
# 911        Steven Spielberg                  194.0  164.435221
# 990             Danny Boyle                  118.0   39.778599
# 1114             Sam Mendes                  323.0   22.877808
# 1422        Randall Wallace                   83.0   56.876365
# 1453         Clint Eastwood                  392.0   37.304950
# 1560              Sam Raimi                   63.0   18.636537
# 2067             Jerry Zaks                   45.0   12.782508
# 2757           Baz Luhrmann                  106.0   46.338728
#
#                                      genres       actor_1_name  \
# 26                         [Drama, Romance]  Leonardo DiCaprio
# 50                         [Drama, Romance]  Leonardo DiCaprio
# 97    [Action, Adventure, Sci-Fi, Thriller]  Leonardo DiCaprio
# 179   [Adventure, Drama, Thriller, Western]  Leonardo DiCaprio
# 257                      [Biography, Drama]  Leonardo DiCaprio
# 296                        [Drama, Western]  Leonardo DiCaprio
# 307            [Adventure, Drama, Thriller]  Leonardo DiCaprio
# 308       [Biography, Comedy, Crime, Drama]  Leonardo DiCaprio
# 326                          [Crime, Drama]  Leonardo DiCaprio
# 361                [Crime, Drama, Thriller]  Leonardo DiCaprio
# 452                     [Mystery, Thriller]  Leonardo DiCaprio
# 641               [Action, Drama, Thriller]  Leonardo DiCaprio
# 911               [Biography, Crime, Drama]  Leonardo DiCaprio
# 990            [Adventure, Drama, Thriller]  Leonardo DiCaprio
# 1114                       [Drama, Romance]  Leonardo DiCaprio
# 1422                    [Action, Adventure]  Leonardo DiCaprio
# 1453              [Biography, Crime, Drama]  Leonardo DiCaprio
# 1560            [Action, Thriller, Western]  Leonardo DiCaprio
# 2067                                [Drama]  Leonardo DiCaprio
# 2757                       [Drama, Romance]  Leonardo DiCaprio
#
#                     movie_title  num_voted_users num_user_for_reviews  \
# 26                     Titanic            793059               2528.0
# 50            The Great Gatsby            362912                753.0
# 97                   Inception           1468200               2803.0
# 179               The Revenant            406020               1188.0
# 257                The Aviator            264318                799.0
# 296           Django Unchained            955174               1193.0
# 307              Blood Diamond            400292                657.0
# 308    The Wolf of Wall Street            780588               1138.0
# 326          Gangs of New York            314033               1166.0
# 361               The Departed            873649               2054.0
# 452             Shutter Island            786092                964.0
# 641               Body of Lies            174248                263.0
# 911        Catch Me If You Can            525801                667.0
# 990                  The Beach            176169                548.0
# 1114        Revolutionary Road            152591                414.0
# 1422  The Man in the Iron Mask            125219                244.0
# 1453                  J. Edgar            102728                279.0
# 1560    The Quick and the Dead             69197                216.0
# 2067             Marvin's Room             20163                 71.0
# 2757            Romeo + Juliet            167750                506.0
#
#      language  budget title_year  imdb_score  movie_facebook_likes  \
# 26    English   200.0     1997.0         7.7                 26000
# 50    English   105.0     2013.0         7.3                115000
# 97    English   160.0     2010.0         8.8                175000
# 179   English   135.0     2015.0         8.1                190000
# 257   English   110.0     2004.0         7.5                     0
# 296   English   100.0     2012.0         8.5                199000
# 307   English   100.0     2006.0         8.0                 14000
# 308   English   100.0     2013.0         8.2                138000
# 326   English   100.0     2002.0         7.5                     0
# 361   English    90.0     2006.0         8.5                 29000
# 452   English    80.0     2010.0         8.1                 53000
# 641   English    70.0     2008.0         7.1                     0
# 911   English    52.0     2002.0         8.0                 15000
# 990   English    50.0     2000.0         6.6                     0
# 1114  English    35.0     2008.0         7.3                     0
# 1422  English    35.0     1998.0         6.4                     0
# 1453  English    35.0     2011.0         6.6                 16000
# 1560  English    32.0     1995.0         6.4                     0
# 2067  English    23.0     1996.0         6.7                  1000
# 2757  English    14.5     1996.0         6.8                 10000
#
#           profit    genre_1    genre_2    genre_3
# 26    458.672302      Drama    Romance      Drama
# 50     39.812796      Drama    Romance      Drama
# 97    132.568851     Action  Adventure     Sci-Fi
# 179    48.635922  Adventure      Drama   Thriller
# 257    -7.391173  Biography      Drama  Biography
# 296    62.804648      Drama    Western      Drama
# 307   -42.633738  Adventure      Drama   Thriller
# 308    16.866727  Biography     Comedy      Crime
# 326   -22.320362      Crime      Drama      Crime
# 361    42.373442      Crime      Drama   Thriller
# 452    47.968405    Mystery   Thriller    Mystery
# 641   -30.619558     Action      Drama   Thriller
# 911   112.435221  Biography      Crime      Drama
# 990   -10.221401  Adventure      Drama   Thriller
# 1114  -12.122192      Drama    Romance      Drama
# 1422   21.876365     Action  Adventure     Action
# 1453    2.304950  Biography      Crime      Drama
# 1560  -13.363463     Action   Thriller    Western
# 2067  -10.217492      Drama      Drama      Drama
# 2757   31.838728      Drama    Romance      Drama

# %%
# Write your code for combining the three dataframes here
Brad_Pitt = movies.loc[movies.actor_1_name == 'Brad Pitt']
Brad_Pitt
# Out:
#               director_name num_critic_for_reviews       gross  \
# 101           David Fincher                  362.0  127.490802
# 147       Wolfgang Petersen                  220.0  133.228348
# 254       Steven Soderbergh                  198.0  125.531634
# 255              Doug Liman                  233.0  186.336103
# 382              Tony Scott                  142.0    0.026871
# 400       Steven Soderbergh                  186.0  183.405771
# 470              David Ayer                  406.0   85.707116
# 611     Jean-Jacques Annaud                   76.0   37.901509
# 683           David Fincher                  315.0   37.023395
# 792         Patrick Gilmore                   98.0   26.288320
# 940             Neil Jordan                  120.0  105.264608
# 1490        Terrence Malick                  584.0   13.303319
# 1722         Andrew Dominik                  273.0    3.904982
# 2204  Alejandro G. Iñárritu                  285.0   34.300771
# 2333    Angelina Jolie Pitt                  131.0    0.531009
# 2682         Andrew Dominik                  414.0   14.938570
# 2898             Tony Scott                  122.0   12.281500
# 4749            Tom DiCillo                   10.0         NaN
#
#                                                  genres actor_1_name  \
# 101                           [Drama, Fantasy, Romance]    Brad Pitt
# 147                                         [Adventure]    Brad Pitt
# 254                                   [Crime, Thriller]    Brad Pitt
# 255          [Action, Comedy, Crime, Romance, Thriller]    Brad Pitt
# 382                           [Action, Crime, Thriller]    Brad Pitt
# 400                                   [Crime, Thriller]    Brad Pitt
# 470                                [Action, Drama, War]    Brad Pitt
# 611         [Adventure, Biography, Drama, History, War]    Brad Pitt
# 683                                             [Drama]    Brad Pitt
# 792   [Adventure, Animation, Comedy, Drama, Family, ...    Brad Pitt
# 940                            [Drama, Fantasy, Horror]    Brad Pitt
# 1490                                   [Drama, Fantasy]    Brad Pitt
# 1722        [Biography, Crime, Drama, History, Western]    Brad Pitt
# 2204                                            [Drama]    Brad Pitt
# 2333                                   [Drama, Romance]    Brad Pitt
# 2682                                  [Crime, Thriller]    Brad Pitt
# 2898          [Action, Crime, Drama, Romance, Thriller]    Brad Pitt
# 4749                           [Comedy, Music, Romance]    Brad Pitt
#
#                                             movie_title  num_voted_users  \
# 101                The Curious Case of Benjamin Button            459346
# 147                                               Troy            381672
# 254                                     Ocean's Twelve            284852
# 255                                   Mr. & Mrs. Smith            348861
# 382                                           Spy Game            121259
# 400                                     Ocean's Eleven            402645
# 470                                               Fury            303185
# 611                               Seven Years in Tibet             96385
# 683                                         Fight Club           1347461
# 792                   Sinbad: Legend of the Seven Seas             36144
# 940   Interview with the Vampire: The Vampire Chroni...           239752
# 1490                                  The Tree of Life            136367
# 1722  The Assassination of Jesse James by the Coward...           136104
# 2204                                             Babel            243799
# 2333                                        By the Sea              7976
# 2682                               Killing Them Softly            111625
# 2898                                      True Romance            163492
# 4749                                      Johnny Suede              3013
#
#      num_user_for_reviews language  budget title_year  imdb_score  \
# 101                 822.0  English   150.0     2008.0         7.8
# 147                1694.0  English   175.0     2004.0         7.2
# 254                 627.0  English   110.0     2004.0         6.4
# 255                 798.0  English   120.0     2005.0         6.5
# 382                 361.0  English    92.0     2001.0         7.0
# 400                 845.0  English    85.0     2001.0         7.8
# 470                 701.0  English    68.0     2014.0         7.6
# 611                 119.0  English    70.0     1997.0         7.0
# 683                2968.0  English    63.0     1999.0         8.8
# 792                  91.0  English    60.0     2003.0         6.7
# 940                 406.0  English    60.0     1994.0         7.6
# 1490                975.0  English    32.0     2011.0         6.7
# 1722                415.0  English    30.0     2007.0         7.5
# 2204                908.0  English    25.0     2006.0         7.5
# 2333                 61.0  English    10.0     2015.0         5.3
# 2682                369.0  English    15.0     2012.0         6.2
# 2898                460.0  English    13.0     1993.0         8.0
# 4749                 24.0  English     0.5     1991.0         5.8
#
#       movie_facebook_likes     profit    genre_1    genre_2    genre_3
# 101                  23000 -22.509198      Drama    Fantasy    Romance
# 147                      0 -41.771652  Adventure  Adventure  Adventure
# 254                      0  15.531634      Crime   Thriller      Crime
# 255                      0  66.336103     Action     Comedy      Crime
# 382                      0 -91.973129     Action      Crime   Thriller
# 400                      0  98.405771      Crime   Thriller      Crime
# 470                  82000  17.707116     Action      Drama        War
# 611                      0 -32.098491  Adventure  Biography      Drama
# 683                  48000 -25.976605      Drama      Drama      Drama
# 792                    880 -33.711680  Adventure  Animation     Comedy
# 940                  11000  45.264608      Drama    Fantasy     Horror
# 1490                 39000 -18.696681      Drama    Fantasy      Drama
# 1722                     0 -26.095018  Biography      Crime      Drama
# 2204                     0   9.300771      Drama      Drama      Drama
# 2333                     0  -9.468991      Drama    Romance      Drama
# 2682                 20000  -0.061430      Crime   Thriller      Crime
# 2898                 15000  -0.718500     Action      Crime      Drama
# 4749                   344        NaN     Comedy      Music    Romance

# %%
# Write your code for grouping the combined dataframe here
Combined = pd.concat([Meryl_Streep, Leo_Caprio, Brad_Pitt])
Combined
# Out:
#               director_name num_critic_for_reviews       gross  \
# 410            Nancy Meyers                  187.0  112.703470
# 1106          Curtis Hanson                   42.0   46.815748
# 1204            Nora Ephron                  252.0   94.125426
# 1408          David Frankel                  208.0  124.732962
# 1483         Robert Redford                  227.0   14.998070
# 1575         Sydney Pollack                   66.0   87.100000
# 1618          David Frankel                  234.0   63.536011
# 1674          Carl Franklin                   64.0   23.209440
# 1752         Stephen Frears                   87.0         NaN
# 1925         Stephen Daldry                  174.0   41.597830
# 2781         Phyllida Lloyd                  331.0   29.959436
# 3135          Robert Altman                  211.0   20.338609
# 3641         Fred Zinnemann                   38.0         NaN
# 26            James Cameron                  315.0  658.672302
# 50             Baz Luhrmann                  490.0  144.812796
# 97        Christopher Nolan                  642.0  292.568851
# 179   Alejandro G. Iñárritu                  556.0  183.635922
# 257         Martin Scorsese                  267.0  102.608827
# 296       Quentin Tarantino                  765.0  162.804648
# 307            Edward Zwick                  166.0   57.366262
# 308         Martin Scorsese                  606.0  116.866727
# 326         Martin Scorsese                  233.0   77.679638
# 361         Martin Scorsese                  352.0  132.373442
# 452         Martin Scorsese                  490.0  127.968405
# 641            Ridley Scott                  238.0   39.380442
# 911        Steven Spielberg                  194.0  164.435221
# 990             Danny Boyle                  118.0   39.778599
# 1114             Sam Mendes                  323.0   22.877808
# 1422        Randall Wallace                   83.0   56.876365
# 1453         Clint Eastwood                  392.0   37.304950
# 1560              Sam Raimi                   63.0   18.636537
# 2067             Jerry Zaks                   45.0   12.782508
# 2757           Baz Luhrmann                  106.0   46.338728
# 101           David Fincher                  362.0  127.490802
# 147       Wolfgang Petersen                  220.0  133.228348
# 254       Steven Soderbergh                  198.0  125.531634
# 255              Doug Liman                  233.0  186.336103
# 382              Tony Scott                  142.0    0.026871
# 400       Steven Soderbergh                  186.0  183.405771
# 470              David Ayer                  406.0   85.707116
# 611     Jean-Jacques Annaud                   76.0   37.901509
# 683           David Fincher                  315.0   37.023395
# 792         Patrick Gilmore                   98.0   26.288320
# 940             Neil Jordan                  120.0  105.264608
# 1490        Terrence Malick                  584.0   13.303319
# 1722         Andrew Dominik                  273.0    3.904982
# 2204  Alejandro G. Iñárritu                  285.0   34.300771
# 2333    Angelina Jolie Pitt                  131.0    0.531009
# 2682         Andrew Dominik                  414.0   14.938570
# 2898             Tony Scott                  122.0   12.281500
# 4749            Tom DiCillo                   10.0         NaN
#
#                                                  genres       actor_1_name  \
# 410                            [Comedy, Drama, Romance]       Meryl Streep
# 1106               [Action, Adventure, Crime, Thriller]       Meryl Streep
# 1204                        [Biography, Drama, Romance]       Meryl Streep
# 1408                           [Comedy, Drama, Romance]       Meryl Streep
# 1483                             [Drama, Thriller, War]       Meryl Streep
# 1575                        [Biography, Drama, Romance]       Meryl Streep
# 1618                           [Comedy, Drama, Romance]       Meryl Streep
# 1674                                            [Drama]       Meryl Streep
# 1752         [Biography, Comedy, Drama, Music, Romance]       Meryl Streep
# 1925                                   [Drama, Romance]       Meryl Streep
# 2781                        [Biography, Drama, History]       Meryl Streep
# 3135                             [Comedy, Drama, Music]       Meryl Streep
# 3641                                            [Drama]       Meryl Streep
# 26                                     [Drama, Romance]  Leonardo DiCaprio
# 50                                     [Drama, Romance]  Leonardo DiCaprio
# 97                [Action, Adventure, Sci-Fi, Thriller]  Leonardo DiCaprio
# 179               [Adventure, Drama, Thriller, Western]  Leonardo DiCaprio
# 257                                  [Biography, Drama]  Leonardo DiCaprio
# 296                                    [Drama, Western]  Leonardo DiCaprio
# 307                        [Adventure, Drama, Thriller]  Leonardo DiCaprio
# 308                   [Biography, Comedy, Crime, Drama]  Leonardo DiCaprio
# 326                                      [Crime, Drama]  Leonardo DiCaprio
# 361                            [Crime, Drama, Thriller]  Leonardo DiCaprio
# 452                                 [Mystery, Thriller]  Leonardo DiCaprio
# 641                           [Action, Drama, Thriller]  Leonardo DiCaprio
# 911                           [Biography, Crime, Drama]  Leonardo DiCaprio
# 990                        [Adventure, Drama, Thriller]  Leonardo DiCaprio
# 1114                                   [Drama, Romance]  Leonardo DiCaprio
# 1422                                [Action, Adventure]  Leonardo DiCaprio
# 1453                          [Biography, Crime, Drama]  Leonardo DiCaprio
# 1560                        [Action, Thriller, Western]  Leonardo DiCaprio
# 2067                                            [Drama]  Leonardo DiCaprio
# 2757                                   [Drama, Romance]  Leonardo DiCaprio
# 101                           [Drama, Fantasy, Romance]          Brad Pitt
# 147                                         [Adventure]          Brad Pitt
# 254                                   [Crime, Thriller]          Brad Pitt
# 255          [Action, Comedy, Crime, Romance, Thriller]          Brad Pitt
# 382                           [Action, Crime, Thriller]          Brad Pitt
# 400                                   [Crime, Thriller]          Brad Pitt
# 470                                [Action, Drama, War]          Brad Pitt
# 611         [Adventure, Biography, Drama, History, War]          Brad Pitt
# 683                                             [Drama]          Brad Pitt
# 792   [Adventure, Animation, Comedy, Drama, Family, ...          Brad Pitt
# 940                            [Drama, Fantasy, Horror]          Brad Pitt
# 1490                                   [Drama, Fantasy]          Brad Pitt
# 1722        [Biography, Crime, Drama, History, Western]          Brad Pitt
# 2204                                            [Drama]          Brad Pitt
# 2333                                   [Drama, Romance]          Brad Pitt
# 2682                                  [Crime, Thriller]          Brad Pitt
# 2898          [Action, Crime, Drama, Romance, Thriller]          Brad Pitt
# 4749                           [Comedy, Music, Romance]          Brad Pitt
#
#                                             movie_title  num_voted_users  \
# 410                                   It's Complicated             69860
# 1106                                    The River Wild             32544
# 1204                                     Julie & Julia             79264
# 1408                             The Devil Wears Prada            286178
# 1483                                   Lions for Lambs             41170
# 1575                                     Out of Africa             52339
# 1618                                      Hope Springs             34258
# 1674                                    One True Thing              9283
# 1752                           Florence Foster Jenkins              2167
# 1925                                         The Hours            102123
# 2781                                     The Iron Lady             82327
# 3135                          A Prairie Home Companion             19655
# 3641                                             Julia              6454
# 26                                             Titanic            793059
# 50                                    The Great Gatsby            362912
# 97                                           Inception           1468200
# 179                                       The Revenant            406020
# 257                                        The Aviator            264318
# 296                                   Django Unchained            955174
# 307                                      Blood Diamond            400292
# 308                            The Wolf of Wall Street            780588
# 326                                  Gangs of New York            314033
# 361                                       The Departed            873649
# 452                                     Shutter Island            786092
# 641                                       Body of Lies            174248
# 911                                Catch Me If You Can            525801
# 990                                          The Beach            176169
# 1114                                Revolutionary Road            152591
# 1422                          The Man in the Iron Mask            125219
# 1453                                          J. Edgar            102728
# 1560                            The Quick and the Dead             69197
# 2067                                     Marvin's Room             20163
# 2757                                    Romeo + Juliet            167750
# 101                The Curious Case of Benjamin Button            459346
# 147                                               Troy            381672
# 254                                     Ocean's Twelve            284852
# 255                                   Mr. & Mrs. Smith            348861
# 382                                           Spy Game            121259
# 400                                     Ocean's Eleven            402645
# 470                                               Fury            303185
# 611                               Seven Years in Tibet             96385
# 683                                         Fight Club           1347461
# 792                   Sinbad: Legend of the Seven Seas             36144
# 940   Interview with the Vampire: The Vampire Chroni...           239752
# 1490                                  The Tree of Life            136367
# 1722  The Assassination of Jesse James by the Coward...           136104
# 2204                                             Babel            243799
# 2333                                        By the Sea              7976
# 2682                               Killing Them Softly            111625
# 2898                                      True Romance            163492
# 4749                                      Johnny Suede              3013
#
#      num_user_for_reviews language  budget title_year  imdb_score  \
# 410                 214.0  English   85.00     2009.0         6.6
# 1106                 69.0  English   45.00     1994.0         6.3
# 1204                277.0  English   40.00     2009.0         7.0
# 1408                631.0  English   35.00     2006.0         6.8
# 1483                298.0  English   35.00     2007.0         6.2
# 1575                200.0  English   31.00     1985.0         7.2
# 1618                178.0  English   30.00     2012.0         6.3
# 1674                112.0  English   30.00     1998.0         7.0
# 1752                 32.0  English   29.00     2016.0         7.1
# 1925                660.0  English   25.00     2002.0         7.6
# 2781                350.0  English   13.00     2011.0         6.4
# 3135                280.0  English   10.00     2006.0         6.8
# 3641                 44.0  English    7.84     1977.0         7.4
# 26                 2528.0  English  200.00     1997.0         7.7
# 50                  753.0  English  105.00     2013.0         7.3
# 97                 2803.0  English  160.00     2010.0         8.8
# 179                1188.0  English  135.00     2015.0         8.1
# 257                 799.0  English  110.00     2004.0         7.5
# 296                1193.0  English  100.00     2012.0         8.5
# 307                 657.0  English  100.00     2006.0         8.0
# 308                1138.0  English  100.00     2013.0         8.2
# 326                1166.0  English  100.00     2002.0         7.5
# 361                2054.0  English   90.00     2006.0         8.5
# 452                 964.0  English   80.00     2010.0         8.1
# 641                 263.0  English   70.00     2008.0         7.1
# 911                 667.0  English   52.00     2002.0         8.0
# 990                 548.0  English   50.00     2000.0         6.6
# 1114                414.0  English   35.00     2008.0         7.3
# 1422                244.0  English   35.00     1998.0         6.4
# 1453                279.0  English   35.00     2011.0         6.6
# 1560                216.0  English   32.00     1995.0         6.4
# 2067                 71.0  English   23.00     1996.0         6.7
# 2757                506.0  English   14.50     1996.0         6.8
# 101                 822.0  English  150.00     2008.0         7.8
# 147                1694.0  English  175.00     2004.0         7.2
# 254                 627.0  English  110.00     2004.0         6.4
# 255                 798.0  English  120.00     2005.0         6.5
# 382                 361.0  English   92.00     2001.0         7.0
# 400                 845.0  English   85.00     2001.0         7.8
# 470                 701.0  English   68.00     2014.0         7.6
# 611                 119.0  English   70.00     1997.0         7.0
# 683                2968.0  English   63.00     1999.0         8.8
# 792                  91.0  English   60.00     2003.0         6.7
# 940                 406.0  English   60.00     1994.0         7.6
# 1490                975.0  English   32.00     2011.0         6.7
# 1722                415.0  English   30.00     2007.0         7.5
# 2204                908.0  English   25.00     2006.0         7.5
# 2333                 61.0  English   10.00     2015.0         5.3
# 2682                369.0  English   15.00     2012.0         6.2
# 2898                460.0  English   13.00     1993.0         8.0
# 4749                 24.0  English    0.50     1991.0         5.8
#
#       movie_facebook_likes      profit    genre_1    genre_2    genre_3
# 410                      0   27.703470     Comedy      Drama    Romance
# 1106                     0    1.815748     Action  Adventure      Crime
# 1204                 13000   54.125426  Biography      Drama    Romance
# 1408                     0   89.732962     Comedy      Drama    Romance
# 1483                     0  -20.001930      Drama   Thriller        War
# 1575                     0   56.100000  Biography      Drama    Romance
# 1618                     0   33.536011     Comedy      Drama    Romance
# 1674                   592   -6.790560      Drama      Drama      Drama
# 1752                     0         NaN  Biography     Comedy      Drama
# 1925                     0   16.597830      Drama    Romance      Drama
# 2781                 18000   16.959436  Biography      Drama    History
# 3135                   683   10.338609     Comedy      Drama      Music
# 3641                   733         NaN      Drama      Drama      Drama
# 26                   26000  458.672302      Drama    Romance      Drama
# 50                  115000   39.812796      Drama    Romance      Drama
# 97                  175000  132.568851     Action  Adventure     Sci-Fi
# 179                 190000   48.635922  Adventure      Drama   Thriller
# 257                      0   -7.391173  Biography      Drama  Biography
# 296                 199000   62.804648      Drama    Western      Drama
# 307                  14000  -42.633738  Adventure      Drama   Thriller
# 308                 138000   16.866727  Biography     Comedy      Crime
# 326                      0  -22.320362      Crime      Drama      Crime
# 361                  29000   42.373442      Crime      Drama   Thriller
# 452                  53000   47.968405    Mystery   Thriller    Mystery
# 641                      0  -30.619558     Action      Drama   Thriller
# 911                  15000  112.435221  Biography      Crime      Drama
# 990                      0  -10.221401  Adventure      Drama   Thriller
# 1114                     0  -12.122192      Drama    Romance      Drama
# 1422                     0   21.876365     Action  Adventure     Action
# 1453                 16000    2.304950  Biography      Crime      Drama
# 1560                     0  -13.363463     Action   Thriller    Western
# 2067                  1000  -10.217492      Drama      Drama      Drama
# 2757                 10000   31.838728      Drama    Romance      Drama
# 101                  23000  -22.509198      Drama    Fantasy    Romance
# 147                      0  -41.771652  Adventure  Adventure  Adventure
# 254                      0   15.531634      Crime   Thriller      Crime
# 255                      0   66.336103     Action     Comedy      Crime
# 382                      0  -91.973129     Action      Crime   Thriller
# 400                      0   98.405771      Crime   Thriller      Crime
# 470                  82000   17.707116     Action      Drama        War
# 611                      0  -32.098491  Adventure  Biography      Drama
# 683                  48000  -25.976605      Drama      Drama      Drama
# 792                    880  -33.711680  Adventure  Animation     Comedy
# 940                  11000   45.264608      Drama    Fantasy     Horror
# 1490                 39000  -18.696681      Drama    Fantasy      Drama
# 1722                     0  -26.095018  Biography      Crime      Drama
# 2204                     0    9.300771      Drama      Drama      Drama
# 2333                     0   -9.468991      Drama    Romance      Drama
# 2682                 20000   -0.061430      Crime   Thriller      Crime
# 2898                 15000   -0.718500     Action      Crime      Drama
# 4749                   344         NaN     Comedy      Music    Romance

# %%
# Group the dataframe by 'actor_1_name'
Combined_by_segment = Combined.groupby('actor_1_name')

# %%
# Remember that we had some null values for the column 'num_critic_for_reviews'. Make sure that none of these null values are
# present in the new dataframe - 'Combined' that we have created

Combined.isnull().sum() # check for null values in the Combined dataframe
# Out:
# director_name             0
# num_critic_for_reviews    0
# gross                     3
# genres                    0
# actor_1_name              0
# movie_title               0
# num_voted_users           0
# num_user_for_reviews      0
# language                  0
# budget                    0
# title_year                0
# imdb_score                0
# movie_facebook_likes      0
# profit                    3
# genre_1                   0
# genre_2                   0
# genre_3                   0
# dtype: int64

# %%
# Find the mean of 'num_user_for_reviews' for each of the actor.
Combined_by_segment['num_user_for_reviews'].mean() # calculate mean of 'num_user_for_reviews' for each actor
# Out:
# actor_1_name
# Brad Pitt            702.444444
# Leonardo DiCaprio        922.55
# Meryl Streep         257.307692
# Name: num_user_for_reviews, dtype: object

# %%
# Find the mean of 'num_critic_for_reviews' for each actor
Combined_by_segment['num_critic_for_reviews'].mean() # calculate mean of 'num_critic_for_reviews' for each actor
# Out:
# actor_1_name
# Brad Pitt            231.944444
# Leonardo DiCaprio         322.2
# Meryl Streep         163.153846
# Name: num_critic_for_reviews, dtype: object

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!

# %%
# Write the code for calculating decade here
import math
def decade(year):
        # Convert the year to an integer before performing arithmetic operations
        year_as_int = int(year)
        return str(math.floor(year_as_int/10) * 10) + 's' # calculate decade by flooring the year to the nearest 10s and appending 's'
movies['decade'] = movies['title_year'].apply(decade) # apply the decade function to the 'title_year' column
movies['decade'] = movies['decade'].astype(str) # convert decade to string type

# %%
# Creating the data frame df_by_decade here 
df_by_decade = movies.groupby(['decade']).num_voted_users.sum().reset_index()
df_by_decade
# Out:
#    decade  num_voted_users
# 0      0s          3115325
# 1   1910s            10718
# 2   1920s           128672
# 3   1930s           984397
# 4   1940s          1211888
# 5   1950s          1616380
# 6   1960s          4997249
# 7   1970s         10737137
# 8   1980s         22086048
# 9   1990s         70178898
# 10  2000s        171295381
# 11  2010s        119965162

# %%
# Plotting number of voted users vs decade
plt.bar(df_by_decade['decade'],df_by_decade['num_voted_users'])
plt.xlabel('decade')
plt.ylabel('Number of voted users')
plt.show()
