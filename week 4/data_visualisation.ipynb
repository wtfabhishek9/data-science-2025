# %% [markdown]
# ### Basic Plotting, Axes Labels and Titles
# - plt.plot() - Create a plot object
# - plt.show() - Explicit command required to display the plot object
# - plt.xlabel(), plt.ylabel() - Specify labels for the X and Y axis respectively
# - plt.title() - Add a title to the plot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Plotting two 1-D numpy arrays
x = np.linspace(5, 100, 100)
y = np.linspace(10, 1000, 100)

plt.plot(x, y)

# %%
plt.plot([1,3,6,8], [3,5,7,9])
plt.show()

# %%
# axis labels and title
plt.plot(x,y)

# x and y labels, and title
plt.xlabel("Current")
plt.ylabel("Voltage")
plt.title("ohm's Law")

# Define the range of labels of the axis
# Arguments: plt.axis(xmin, xmax, ymin, ymax)
plt.xlim([20, 80])
plt.ylim([200, 800])
plt.show()

# %%
# change the colors and line type

# initialising x and y arrays
x = np.linspace(0, 10, 20)
y = x * 2

# color blue, line type '+'
plt.plot(x, y, 'b+')

# put x and y labels, and the title
plt.xlabel("Current")
plt.ylabel("Voltage")
plt.title("ohm's Law")
plt.show()

# %%
x = np.linspace(1, 10, 100)
y = np.log(x)

# initiate a new figure explicitly
plt.figure(1)

# create a sublot with 1 Row, 2 columns

# create the first subplot in figure 1
plt.subplot(121)  # equivalent to plt.subplot(1,2,1)
plt.title("y = log(x)")
plt.plot(x, y)

# create the second subplot in figure 1
plt.subplot(122)
plt.title("y = log(x) **2")
plt.plot(x, y ** 2)
plt.show()

# %%
# example: create a figure having 4 subplots
x = np.linspace(1, 10, 100)

# optional command, since matplotlib create a figure by default anyway
plt.figure(1)

# subplot 2
plt.subplot(2,2,1)
plt.title("Cubic")
plt.plot(x, x**3) # x^3

# subplot 1
plt.subplot(2,2,3)
plt.title("Linear")
plt.plot(x, x) # x^1

# subplot 3
plt.subplot(2,2,2)
plt.title("Log")
plt.plot(x, np.log(x))

# subplot 4
plt.subplot(2,2,4)
plt.title("Exponential")
plt.plot(x, np.log(x))

plt.show()

# %% [markdown]
# - Boxplots
# - Histograms
# - Scatter plots
#  - Bar plots

# %%
# Example: Globals sales data
df = pd.read_csv("./global_sales_data/market_fact.csv")
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %% [markdown]
# ### Boxplots

# %%
# boxplot: visualise the distribution of a continuous  variable
plt.boxplot(df['Order_Quantity'])
plt.show()

# %%
# Boxplot of sales is quite unreadable, since sales varies
# across a wide range
plt.boxplot(df['Sales'])
plt.show()

# %%
# Range of sales : min 2.24, median is 449, max is 89061
df ['Sales'].describe()
# Out:
# count     8399.000000
# mean      1775.878179
# std       3585.050525
# min          2.240000
# 25%        143.195000
# 50%        449.420000
# 75%       1709.320000
# max      89061.050000
# Name: Sales, dtype: float64

# %%
# usual (linear) scale subplot
plt.subplot(1,2,1)
plt.boxplot(df['Sales'])

# log scale subplot
plt.subplot(1,2,2)
plt.boxplot(df['Sales'])
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Histogram

# %%
# Histogram
plt.hist(df['Sales'])
plt.show()

# %%
# The histogram can be made more readable by using a log scale

plt.hist(df['Sales'])
plt.yscale('log')
plt.show()

# %% [markdown]
# #### Scatter Plot
# Scatter plots are used to visualise two variables, one one each axis.

# %%
# Scatter plots with two variables: Profit and Sales
plt.scatter(df['Sales'], df['Profit'])
plt.show()

# %%
# import a seaborn library
import seaborn as sns

# set a seaborn style for your taste
sns.set_style("whitegrid")

# data
df = pd.read_csv("./global_sales_data/market_fact.csv")

# %%
# simple density plot
# distplot is deprecated so we use kdeplot here;
sns.kdeplot(df['Shipping_Cost'])
plt.show()

# %%
# simple density plot
sns.displot(df['Shipping_Cost'])
plt.show()

# %%
sns.distplot(df['Shipping_Cost'][: 200], rug = True)
plt.show()
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_17708\319074129.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Shipping_Cost'][: 200], rug = True)

# %%
sns.distplot(df['Sales'], hist = False)
plt.show()
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_17708\3967492298.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Sales'], hist = False)

# %%
# subplots

# subplots 1
plt.subplot(2,2,1)
plt.title('Sales')
sns.distplot(df['Sales'])

# subplot 2
plt.subplot(2,2,2)
plt.title('Profit')
sns.distplot(df['Profit'])

# subplot 3
plt.subplot(2,2,3)
plt.title('Order Quantity')
sns.distplot(df['Order_Quantity'])

# subplot 4
plt.subplot(2,2,4)
plt.title('Shipping Cost')
sns.distplot(df['Shipping_Cost'])

plt.show()
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_17708\67168069.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Sales'])
# C:\Users\abhis\AppData\Local\Temp\ipykernel_17708\67168069.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Profit'])
# ...

# %%
# subplots

# subplots 1
plt.subplot(2,2,1)
plt.title('Sales')
sns.kdeplot(df['Sales'])

# subplot 2
plt.subplot(2,2,2)
plt.title('Profit')
sns.kdeplot(df['Profit'])

# subplot 3
plt.subplot(2,2,3)
plt.title('Order Quantity')
sns.kdeplot(df['Order_Quantity'])

# subplot 4
plt.subplot(2,2,4)
plt.title('Shipping Cost')
sns.kdeplot(df['Shipping_Cost'])

plt.show()

# %%
# boxplot
sns.boxplot(df['Order_Quantity'])  # horizontal boxplot
plt.title('Order Quantity')  # title
plt.show()

# %%
# to plot the values on the vertical axis, specify y = variable
sns.boxplot(y = df['Order_Quantity']) # vertical boxplot because y = variable
plt.title('Order Quantity')
plt.show()

# %%
# create a rug plot of the first 1000 Sales values using the distplot() function
sns.distplot(df['Sales'][: 1000], rug = True)
plt.show()
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_17708\1475705929.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Sales'][: 1000], rug = True)

# %%
# joint plots of Profit and Sales
sns.jointplot(x = 'Sales', y = 'Profit', data = df)
plt.show()

# Same as sns.jointplot(df['Sales'], df['Profit'])

# %%
# remove points having extreme values
df = df[(df.Profit < 10000)  & (df.Sales < 20000)]
sns.jointplot(x = 'Sales', y = 'Profit', data = df)
plt.show()

# %%
# plotting Low Sales value order
# hex plot
df = pd.read_csv("./global_sales_data/market_fact.csv")
df = df[(df.Profit < 100)  & (df.Profit > -100) & (df.Sales < 200)]
sns.jointplot(x = 'Sales', y = 'Profit', data = df, kind = "hex", color = "k")
plt.show()

# %%
# reading cryptocurrency files
btc = pd.read_csv("./crypto_data/bitcoin_price.csv")
ether = pd.read_csv("./crypto_data/ethereum_price.csv")
ltc = pd.read_csv("crypto_data/litecoin_price.csv")
monero = pd.read_csv("crypto_data/monero_price.csv")
neo = pd.read_csv("crypto_data/neo_price.csv")
quantum =pd.read_csv("crypto_data/qtum_price.csv")
ripple = pd.read_csv("crypto_data/ripple_price.csv")

# putting a suffix with column names so that joins are easy
btc.columns = btc.columns.map(lambda x: str(x) + '_btc')
ether.columns = ether.columns.map(lambda x: str(x) + '_et')
ltc.columns = ltc.columns.map(lambda x: str(x) + '_ltc')
monero.columns = monero.columns.map(lambda x: str(x) + '_mon')
neo.columns = neo.columns.map(lambda x: str(x) + '_neo')
quantum.columns = quantum.columns.map(lambda x: str(x) + '_qt')
ripple.columns = ripple.columns.map(lambda x: str(x) + '_rip')

btc.head()
# Out:
#        Date_btc  Open_btc  High_btc  Low_btc  Close_btc     Volume_btc  \
# 0  Nov 07, 2017   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1  Nov 06, 2017   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2  Nov 05, 2017   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3  Nov 04, 2017   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4  Nov 03, 2017   7087.53   7461.29  7002.94    7207.76  3,369,860,000
#
#     Market Cap_btc
# 0  117,056,000,000
# 1  123,379,000,000
# 2  123,388,000,000
# 3  119,376,000,000
# 4  118,084,000,000

# %%
# merging all the files by date
m1 = pd.merge(btc, ether, how = "inner", left_on = "Date_btc", right_on = "Date_et")
m2 = pd.merge(m1, ltc, how = "inner", left_on = "Date_btc", right_on = "Date_ltc")
m3 = pd.merge(m2, monero, how = "inner", left_on = "Date_btc", right_on = "Date_mon")
m4 = pd.merge(m3 , neo, how = "inner", left_on = "Date_btc", right_on = "Date_neo")
m5 = pd.merge(m4, quantum, how = "inner", left_on = "Date_btc", right_on = "Date_qt")
crypto = pd.merge(m5, ripple, how = "inner", left_on = "Date_btc", right_on = "Date_rip")
crypto.head()
# Out:
#        Date_btc  Open_btc  High_btc  Low_btc  Close_btc     Volume_btc  \
# 0  Nov 07, 2017   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1  Nov 06, 2017   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2  Nov 05, 2017   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3  Nov 04, 2017   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4  Nov 03, 2017   7087.53   7461.29  7002.94    7207.76  3,369,860,000
#
#     Market Cap_btc       Date_et  Open_et  High_et  ...  Close_qt  \
# 0  117,056,000,000  Nov 07, 2017   298.57   304.84  ...     11.21
# 1  123,379,000,000  Nov 06, 2017   296.43   305.42  ...     10.44
# 2  123,388,000,000  Nov 05, 2017   300.04   301.37  ...     10.13
# 3  119,376,000,000  Nov 04, 2017   305.48   305.48  ...     10.05
# 4  118,084,000,000  Nov 03, 2017   288.50   308.31  ...     10.38
#
#      Volume_qt Market Cap_qt      Date_rip  Open_rip  High_rip   Low_rip  \
# ...

# %%
crypto.columns
# Out:
# Index(['Date_btc', 'Open_btc', 'High_btc', 'Low_btc', 'Close_btc',
#        'Volume_btc', 'Market Cap_btc', 'Date_et', 'Open_et', 'High_et',
#        'Low_et', 'Close_et', 'Volume_et', 'Market Cap_et', 'Date_ltc',
#        'Open_ltc', 'High_ltc', 'Low_ltc', 'Close_ltc', 'Volume_ltc',
#        'Market Cap_ltc', 'Date_mon', 'Open_mon', 'High_mon', 'Low_mon',
#        'Close_mon', 'Volume_mon', 'Market Cap_mon', 'Date_neo', 'Open_neo',
#        'High_neo', 'Low_neo', 'Close_neo', 'Volume_neo', 'Market Cap_neo',
#        'Date_qt', 'Open_qt', 'High_qt', 'Low_qt', 'Close_qt', 'Volume_qt',
#        'Market Cap_qt', 'Date_rip', 'Open_rip', 'High_rip', 'Low_rip',
#        'Close_rip', 'Volume_rip', 'Market Cap_rip'],
#       dtype='object')

# %%
# subsetting only the closing prices colum for plotting
curr = crypto[["Close_btc", "Close_et", 'Close_ltc', "Close_mon", "Close_neo", "Close_qt"]]
curr.head()
# Out:
#    Close_btc  Close_et  Close_ltc  Close_mon  Close_neo  Close_qt
# 0    7144.38    294.66      61.30      99.76      26.23     11.21
# 1    7022.76    298.89      55.17     102.92      26.32     10.44
# 2    7407.41    296.26      54.75      86.35      26.38     10.13
# 3    7379.95    300.47      55.04      87.30      26.49     10.05
# 4    7207.76    305.71      56.18      87.99      26.82     10.38

# %%
# pairplot
sns.pairplot(curr)
plt.show()

# %%
# you can also observe the correlation between the currencies
# using df.corr()
cor = curr.corr() # correlation matrix of cryptocurrencies
round(cor, 3)  # round to 3 decimal places
# Out:
#            Close_btc  Close_et  Close_ltc  Close_mon  Close_neo  Close_qt
# Close_btc      1.000     0.449      0.658      0.697      0.735     0.382
# Close_et       0.449     1.000      0.490      0.539      0.482     0.791
# Close_ltc      0.658     0.490      1.000      0.793      0.641     0.448
# Close_mon      0.697     0.539      0.793      1.000      0.669     0.518
# Close_neo      0.735     0.482      0.641      0.669      1.000     0.557
# Close_qt       0.382     0.791      0.448      0.518      0.557     1.000

# %%
# figure size
plt.figure(figsize=(10,8)) # 10 inches wide, 8 inches tall

# heatmap
sns.heatmap(cor, cmap="YlGnBu", annot=True) # annot=True to show the correlation values
plt.show()

# %%
# set seaborn theme if you prefer
sns.set(style = "white")

# Read data
market_df = pd.read_csv("./global_sales_data/market_fact.csv")
customer_df = pd.read_csv("./global_sales_data/cust_dimen.csv")
product_df = pd.read_csv("./global_sales_data/prod_dimen.csv")
shipping_df = pd.read_csv("./global_sales_data/shipping_dimen.csv")
orders_df = pd.read_csv("./global_sales_data/orders_dimen.csv")

# %%
# boxplot of a variable
sns.boxplot(y = market_df['Sales'])
plt.yscale('log')
plt.show()

# %% [markdown]
# Based on the error in the code, the merge operation is failing because the column `prod_id` doesn't have matching case between `market_df` and `customer_df`. Looking at the DataFrames, customer_df has `Cust_id` while market_df has `Cust_id`, so we should merge on that instead.

# %%
# merge the dataframe to add a categorial variable to the dataframe
df = pd.merge(market_df, product_df, how='inner', on='prod_id')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17708\3400234184.py in ?()
#       1 # merge the dataframe to add a categorial variable to the dataframe
# ----> 2 df = pd.merge(market_df, product_df, how='inner', on='prod_id')
#       3 df.head()
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ...

# %%
# boxplot of a variable across various product categories
sns.boxplot(x = 'Product_Category', y = 'Sales', data = df)
plt.yscale('log')  # log scale
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 # boxplot of a variable across various product categories
# ----> 2 sns.boxplot(x = 'Product_Category', y = 'Sales', data = df)
#       3 plt.yscale('log')  # log scale
#       4 plt.show()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
# ...

# %%
# boxplot of a variable across various product categories
sns.boxplot(x = 'Customer_Segment', y = 'Profit', data = df)
plt.show()

# %%
# set figure size for larger figure
plt.figure(num = None, figsize = (12, 8), dpi = 80, facecolor = 'w', edgecolor = 'k')

# specify hue = "Categorial_Variable"
sns.boxplot(x = 'Customer_Segment', y = 'Profit', hue = "Product_Category", data = df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 5
#       2 plt.figure(num = None, figsize = (12, 8), dpi = 80, facecolor = 'w', edgecolor = 'k')
#       4 # specify hue = "Categorial_Variable"
# ----> 5 sns.boxplot(x = 'Customer_Segment', y = 'Profit', hue = "Product_Category", data = df)
#       6 plt.show()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# ...

# %%
# set seaborn theme if you prefer
sns.set(style = "white")

# Read data
market_df = pd.read_csv("./global_sales_data/market_fact.csv")
customer_df = pd.read_csv("./global_sales_data/cust_dimen.csv")
product_df = pd.read_csv("./global_sales_data/prod_dimen.csv")
shipping_df = pd.read_csv("./global_sales_data/shipping_dimen.csv")
orders_df = pd.read_csv("./global_sales_data/orders_dimen.csv")

# %%
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
df = pd.merge(market_df, orders_df, how = 'inner', on = 'Ord_id')
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin  Order_ID  Order_Date  \
# 0   -30.51           3.60                 0.56     36262  27-07-2010
# 1     4.56           0.93                 0.54     20513  07-07-2009
# 2  1148.90           2.50                 0.59     36262  27-07-2010
# 3   729.34          14.30                 0.37     39682  09-11-2010
# 4  1219.87          26.30                 0.38     54019  01-07-2009
#
#   Order_Priority
# 0  NOT SPECIFIED
# 1           HIGH
# 2  NOT SPECIFIED
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
#  10  Order_ID             8399 non-null   int64
#  11  Order_Date           8399 non-null   object
#  12  Order_Priority       8399 non-null   object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 853.2+ KB

# %%
# Convert Order_Date to Datetime type
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# order Date is noe datetime type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
#  10  Order_ID             8399 non-null   int64
#  11  Order_Date           8399 non-null   datetime64[ns]
#  12  Order_Priority       8399 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 853.2+ KB

# %%
# aggregating total sales on each day
time_df = df.groupby('Order_Date')['Sales'].sum()
print(time_df.head())
print(type(time_df))
# Out:
# Order_Date
# 2009-01-01     1052.8400
# 2009-01-02    11101.8700
# 2009-01-03    31997.8555
# 2009-01-04     1254.2500
# 2009-01-05    39734.4040
# Name: Sales, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
# time series plot

# figure size
plt.figure(figsize = (16, 8))

# tsplot
sns.lineplot(x=time_df.index, y=time_df.values)
plt.show()

# %%
# extracting month and year from date

# extract month
df['month'] = df['Order_Date'].dt.month

# extract year
df['year'] = df['Order_Date'].dt.year

df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin  Order_ID Order_Date  \
# 0   -30.51           3.60                 0.56     36262 2010-07-27
# 1     4.56           0.93                 0.54     20513 2009-07-07
# 2  1148.90           2.50                 0.59     36262 2010-07-27
# 3   729.34          14.30                 0.37     39682 2010-11-09
# 4  1219.87          26.30                 0.38     54019 2009-07-01
#
#   Order_Priority  month  year
# 0  NOT SPECIFIED      7  2010
# 1           HIGH      7  2009
# ...

# %%
# grouping by month and year
df_time = df.groupby(["year", "month"]).Sales.mean()
df_time.head()
# Out:
# year  month
# 2009  1        2315.259908
#       2        2187.372609
#       3        2225.020157
#       4        2286.491174
#       5        1264.535923
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(8, 6))
# time series plot
sns.lineplot(df_time)
plt.xlabel("Time")
plt.ylabel("Sales")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# TypeError: Invalid object type
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 3
#       1 plt.figure(figsize=(8, 6))
#       2 # time series plot
# ----> 3 sns.lineplot(df_time)
#       4 plt.xlabel("Time")
#       5 plt.ylabel("Sales")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\relational.py:515, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     512 color = kwargs.pop("color", kwargs.pop("c", None))
# ...
